# %% [markdown]
# # markdown
# ## markdown
# ### markdown
# #### markdown
# ##### markdown
# ###### markdown

# %% [markdown]
# # insert site address
# [site](http://gitamstudent.gitam.edu/STUDENT/Login.aspx)

# %% [markdown]
# # insert image
# [image](https://previews.123rf.com/images/visarts/visarts1512/visarts151200084/49354199-hipster-beard-pipe.jpg)

# %% [markdown]
# # Python Basics:
# -Python is a beginner's language
# -Python is to learn
# #creating order list
# 1.abs
# 2.hsdf
#    1.a
#    2.b

# %% [markdown]
# # unordered list
#
#
# *   qwe
# *   qwent
#          .asd
#          .adgh

# %% [markdown]
# ## bold and italic text
# **GITAM**
#
# *GITAM*

# %%
#BASIC HELLO TEXT
print("hello world!")
# Out:
# hello world!

# %%
# variable creation
x=10
y=20
x + y
# Out:
# 30

# %% [markdown]
# # rules for variable
#  -name should begin eith character
#
#  -no special characters allowed except_

# %%
name="ajay"

# %%
age=20

# %%
print("my name is:",name,"age is:",age)
# Out:
# my name is: ajay age is: 20

# %%
name = input("enter Name")
age=int(input("enter age"))
print("my name is:",name,"age is:",age)
# Out:
# enter Namebunny
# enter age 18
# my name is: bunny age is: 18

# %% [markdown]
# # TAKE 2 INPUT

# %%
a=int(input("value of a"))
b=int(input("value of b"))
print("a+b=",a+b,"a*b=",a*b,"a/b=",a/b,"a-b=",a-b)
# Out:
# value of a30
# value of b 20
# a+b= 50 a*b= 600 a/b= 1.5 a-b= 10

# %% [markdown]
# # fundamental datatype
#  * float
#  * int
#  * complex
#  * boolean
#  * string

# %%
x=10
y=12.56
z=5+6j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
c=complex(5,10)
print(c)
# Out:
# (5+10j)

# %%
c1=3+5j
c2=6+7j
print(c1+c2)
print(c1-c2)
print(c1*c2)
# Out:
# (9+12j)
# (-3-2j)
# (-17+51j)

# %%
# boolean
x=10
y=20
print(x>y)
print(x<y)
# Out:
# False
# True

# %%
#string
s1="abc"
s2="dfg"
print(type(s1))
print(type(s2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
i=100
print(type(i))
s1=str(i)
print(type(s1))
f1=float(i)
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# Length
a=1234
print(len(str(a)))
# Out:
# 4

# %%
n1=100
a=b=c=20
a1,b1,c1=123,152,369
print(n1)
print(a,b,c)
print(a1,b1,c1)
# Out:
# 100
# 20 20 20
# 123 152 369

# %% [markdown]
# # precendence of the arth operation
#  - parenthsis
#  - power
#  - multiplication
#  - addition

# %%
x=1+2**3/4+5
print(x)
# Out:
# 8.0

# %%
x=1+2**3/4*5
print(x)
# Out:
# 11.0

# %% [markdown]
# # operators
# ### Arithmetic operators
# - +
# - -
# - *
# - /
# - %
# - **
# - //

# %%
a=10
b=50
print(a+b)
# Out:
# 60

# %%
a=10
b=5
print(a//b)
# Out:
# 2

# %% [markdown]
# # Relation Operators
# - "=="
# - "!="
# - "<"
# - ">"
# - "<="
# - ">="

# %%
x=5
a=x>10
print(a)
# Out:
# False

# %% [markdown]
# # logical operator
# - and
# -or
# -not

# %%
#check given number is even or odd
n=int(input("enter a number"))
if n%2==0:
 print("even")
else:
  print("odd")
# Out:
# enter a number10
# even

# %%
n=int(input("enter a number"))
if n%3==0 and n%5==0:
 print("YES")
else:
  print("NO")
# Out:
# enter a number15
# YES

# %%
n=int(input("enter a number"))
if n==0:
 print("zero")
elif n<0:
  print("negitive")
else n>0:
  print("positive")
# Out:
#   File "<ipython-input-39-aee78d47ea2a>", line 6
#     else n>0:
#          ^
# SyntaxError: invalid syntax
